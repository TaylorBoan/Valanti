# %%
import pandas as pd

# %%
# Opening the listing_urls.csv with pandas
listing_urls = pd.read_csv('Car Models/listing_urls.csv')
# Out:
# /var/folders/lr/851f4nld2ws1hc6311gxkzdw0000gn/T/ipykernel_37517/1517005858.py:2: DtypeWarning: Columns (6,27,31,35,50,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   listing_urls = pd.read_csv('Car Models/listing_urls.csv')

# %%
# Priting the total number of rows in the CSV file
print(listing_urls_csv.shape[0])

# %%
# Viewing the number of rows for each Model
print(listing_urls['model'].value_counts())
# Out:
# model
# Urus             22285
# 720 S             7935
# 458               6095
# California        5566
# Gallardo          5470
# SF90              5341
# F430              5296
# 570S              5274
# 812               5161
# Portofino         4623
# Roma              4331
# 600 LT            3291
# 650 S             1758
# Aventador SVJ     1716
# 488 (Pista)       1706
# Murcielago         924
# Aventador SV       300
# LaFerrari          180
# Mclaren:           150
# Sian                53
# F8                  43
# Name: count, dtype: int64

# %%
# Printing all of the columns in the csv file
print(listing_urls.columns)
# Out:
# Index(['archiveDate', 'backendModel', 'backendSitecode', 'bids', 'countryCode',
#        'ctime', 'currentBid', 'date', 'dealGauge', 'dealGaugeClass',
#        'dealGaugeIcon', 'dealerName', 'detailsExtraLong', 'detailsLong',
#        'detailsMid', 'detailsShort', 'distance', 'endDate', 'externalId',
#        'hasPic', 'highlightUnseen', 'hotCar', 'id', 'img', 'imgFallback',
#        'imgSource', 'isHotCar', 'isSold', 'listingHistory', 'listingType',
#        'location', 'locationCode', 'logoSrc', 'make', 'mileage', 'misc',
#        'model', 'pendingSale', 'phone', 'placeholderImgSrc', 'price',
#        'priceHistory', 'priceHistoryDiff', 'priceHistoryExtended',
#        'priceRecentChange', 'sellerType', 'shareIsSupported', 'sitecode',
#        'sourceCodeString', 'sourceName', 'timeLeft', 'title', 'trim', 'urg',
#        'url', 'vehicleTitle', 'vehicleTitleDesc', 'vehicleTitleSource', 'vin',
#        'year'],
#       dtype='object')

# %%
# Printing all of the unique values in the "model" column
print(listing_urls.model.unique())
# Out:
# ['Aventador SV' 'Aventador SVJ' 'Gallardo' 'Urus' 'Murcielago' 'Sian'
#  '458' '488 (Pista)' '812' 'SF90' 'LaFerrari' 'California' 'F430' 'F8'
#  'Portofino' 'Roma' 'Mclaren:' '570S' '600 LT' '650 S' '720 S']
